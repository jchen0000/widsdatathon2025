# %% [markdown]
# <a href="https://colab.research.google.com/github/jchen0000/widsdatathon2025/blob/main/yiru_notebook_test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
# import matplotlib.pyplot as plt
# import seaborn as sns

# %% [markdown]
# # Data Loading

# %% [markdown]
# ## Method 1: load from google drive
# ps: colab cannot access shared folders, thus need to first m=copy the datasets to your own location

# %%
# prompt: mount the notebook with current folder

from google.colab import drive
drive.mount('/content/drive')

## suppose you've created a folder named "widsdatathon2025"
# %cd /content/drive/MyDrive/widsdatathon2025/
# %ls
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/drive/MyDrive/widsdatathon2025
# 'Data Dictionary.xlsx'   SAMPLE_SUBMISSION.xlsx   TEST/   TRAIN/   Work/

# %%
df = pd.read_excel('SAMPLE_SUBMISSION.xlsx')
df.head()
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   Cfwaf5FX7jWK             1      0
# 1   vhGrzmvA3Hjq             0      0
# 2   ULliyEXjy4OV             0      1
# 3   LZfeAb1xMtql             1      0
# 4   EnFOUv0YK1RG             1      0

# %% [markdown]
# ## Method 2: Clone from github

# %%
# %cd /content/
# !git clone https://github.com/jchen0000/widsdatathon2025.git
# Out:
# /content
# Cloning into 'widsdatathon2025'...
# remote: Enumerating objects: 123, done.
# remote: Counting objects: 100% (62/62), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 123 (delta 26), reused 35 (delta 10), pack-reused 61 (from 2)
# Receiving objects: 100% (123/123), 50.54 MiB | 34.20 MiB/s, done.
# Resolving deltas: 100% (38/38), done.
# Filtering content: 100% (2/2), 557.95 MiB | 30.22 MiB/s, done.

# %%
# !git config --global user.email ygong2832@gmail.com
# !git config --global user.name yiruGONG

# %%
# %cd /content/widsdatathon2025
# %ls
# Out:
# /content/widsdatathon2025
# data/  python/  r/  README.md  widsdatathon2025.Rproj

# %%
df = pd.read_excel("data/SAMPLE_SUBMISSION.xlsx")
df.head()
# Out:
#   participant_id  ADHD_Outcome  Sex_F
# 0   Cfwaf5FX7jWK             1      0
# 1   vhGrzmvA3Hjq             0      0
# 2   ULliyEXjy4OV             0      1
# 3   LZfeAb1xMtql             1      0
# 4   EnFOUv0YK1RG             1      0

# %% [markdown]
# ## Load data

# %%
# %cd /content/widsdatathon2025
# %ls data/test/
# Out:
# /content/widsdatathon2025
# TEST_CATEGORICAL.xlsx  TEST_FUNCTIONAL_CONNECTOME_MATRICES.csv  TEST_QUANTITATIVE_METADATA.xlsx

# %%
# training data
df_train_mri = pd.read_csv("./data/train/TRAIN_FUNCTIONAL_CONNECTOME_MATRICES.csv")
print(df_train_mri.shape)
df_train_mri.head()
# Out:
# (1213, 19901)
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   70z8Q2xdTXM3          0.093473          0.146902          0.067893
# 1   WHWymJu6zNZi          0.029580          0.179323          0.112933
# 2   4PAQp1M6EyAo         -0.051580          0.139734          0.068295
# 3   obEacy4Of68I          0.016273          0.204702          0.115980
# 4   s7WzzDcmDOhF          0.065771          0.098714          0.097604
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.015141          0.070221          0.063997          0.055382
# 1          0.038291          0.104899          0.064250          0.008488
# 2          0.046991          0.111085          0.026978          0.151377
# 3          0.043103          0.056431          0.057615          0.055773
# 4          0.112988          0.071139          0.085607          0.019392
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# ...

# %%
df_train_mri.describe()
# Out:
#        0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  0throw_4thcolumn  \
# count       1213.000000       1213.000000       1213.000000       1213.000000
# mean           0.060553          0.122315          0.060268          0.041287
# std            0.064178          0.054026          0.057495          0.043491
# min           -0.183279         -0.059932         -0.145566         -0.127827
# 25%            0.018482          0.086102          0.026548          0.014457
# 50%            0.058276          0.123220          0.061339          0.043246
# 75%            0.100103          0.154518          0.099056          0.068408
# max            0.321522          0.390895          0.278429          0.189825
#
#        0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  0throw_8thcolumn  \
# count       1213.000000       1213.000000       1213.000000       1213.000000
# mean           0.069722          0.091007          0.066852          0.000252
# ...

# %%
df_train_meta_quant = pd.read_excel("./data/train/TRAIN_QUANTITATIVE_METADATA.xlsx")
print(df_train_meta_quant.shape)
df_train_meta_quant.describe()
# df_train_meta_quant.head()
# Out:
# (1213, 19)
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count    1213.000000           1213.000000     1213.000000     1213.000000
# mean       58.876917             13.164880        3.781533       13.205276
# std        49.855501              2.780624        1.376700        3.811772
# min      -100.000000              0.000000        0.000000        0.000000
# 25%        45.600000             14.000000        3.000000       11.000000
# 50%        76.670000             14.000000        3.000000       13.000000
# 75%        93.400000             14.000000        4.000000       16.000000
# max       100.000000             14.000000       12.000000       28.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count      1213.000000      1213.000000     1213.000000     1213.000000
# mean         39.374279        17.785655       16.393240       25.246496
# ...

# %%
df_train_meta_cat = pd.read_excel("./data/train/TRAIN_CATEGORICAL_METADATA.xlsx")
print(df_train_meta_cat.shape)
# df_train_meta_cat.head()

# Display value counts for each column in df_train_meta_cat
for col in df_train_meta_cat.columns[1:]:
  print(f"Value counts for column '{col}':\n{df_train_meta_cat[col].value_counts()}\n")
# Out:
# (1213, 10)
# Value counts for column 'Basic_Demos_Enroll_Year':
# Basic_Demos_Enroll_Year
# 2018    415
# 2019    312
# 2017    254
# 2016    191
# 2015     36
# 2020      5
# Name: count, dtype: int64
#
# Value counts for column 'Basic_Demos_Study_Site':
# Basic_Demos_Study_Site
# 1    652
# 3    430
# 4    120
# 2     11
# Name: count, dtype: int64
#
# Value counts for column 'PreInt_Demos_Fam_Child_Ethnicity':
# PreInt_Demos_Fam_Child_Ethnicity
# 0.0    809
# 1.0    296
# 2.0     77
# 3.0     20
# Name: count, dtype: int64
#
# Value counts for column 'PreInt_Demos_Fam_Child_Race':
# PreInt_Demos_Fam_Child_Race
# 0     627
# 8     195
# 1     181
# 2     128
# 3      30
# 9      23
# 10     11
# 4      10
# 11      6
# 7       2
# Name: count, dtype: int64
#
# Value counts for column 'MRI_Track_Scan_Location':
# MRI_Track_Scan_Location
# 2    532
# 3    463
# 1    179
# 4     36
# 0      3
# Name: count, dtype: int64
#
# Value counts for column 'Barratt_Barratt_P1_Edu':
# ...

# %%
df_train_y = pd.read_excel("./data/train/TRAINING_SOLUTIONS.xlsx")
print(df_train_y.shape)
df_train_y.head()
# Out:
# (1213, 3)
#   participant_id  ADHD_Outcome  Sex_F
# 0   UmrK0vMLopoR             1      1
# 1   CPaeQkhcjg7d             1      0
# 2   Nb4EetVPm3gs             1      0
# 3   p4vPhVu91o4b             1      1
# 4   M09PXs7arQ5E             1      1

# %%
# Test data
df_test_mri = pd.read_csv("./data/test/TEST_FUNCTIONAL_CONNECTOME_MATRICES.csv")
print(df_test_mri.shape)
df_test_mri.head()
# Out:
# (304, 19901)
#   participant_id  0throw_1thcolumn  0throw_2thcolumn  0throw_3thcolumn  \
# 0   Cfwaf5FX7jWK          0.548480          0.713607          0.557319
# 1   vhGrzmvA3Hjq          0.427740          0.363022          0.402862
# 2   ULliyEXjy4OV          0.139572          0.390106         -0.087041
# 3   LZfeAb1xMtql          0.133561          0.778326          0.416355
# 4   EnFOUv0YK1RG          0.126699          0.575446          0.509422
#
#    0throw_4thcolumn  0throw_5thcolumn  0throw_6thcolumn  0throw_7thcolumn  \
# 0          0.524369          0.693364          0.770032          0.724406
# 1          0.363003          0.534558          0.345347          0.409471
# 2          0.196852          0.088148          0.023843          0.381782
# 3          0.471840          0.568460          0.633660          0.501113
# 4          0.363193          0.427544          0.449924          0.451796
#
#    0throw_8thcolumn  0throw_9thcolumn  ...  195throw_196thcolumn  \
# ...

# %%
df_test_meta_quant = pd.read_excel("./data/test/TEST_QUANTITATIVE_METADATA.xlsx")
print(df_test_meta_quant.shape)
df_test_meta_quant.describe()
# Out:
# (304, 19)
#        EHQ_EHQ_Total  ColorVision_CV_Score  APQ_P_APQ_P_CP  APQ_P_APQ_P_ID  \
# count     303.000000            295.000000      289.000000      289.000000
# mean       59.144488             13.240678        3.321799       13.259516
# std        49.330962              1.986273        0.810248        3.627411
# min      -100.050000              0.000000        2.000000        6.000000
# 25%        50.060000             13.000000        3.000000       11.000000
# 50%        73.370000             14.000000        3.000000       13.000000
# 75%        93.380000             14.000000        3.000000       16.000000
# max       100.050000             14.000000        8.000000       23.000000
#
#        APQ_P_APQ_P_INV  APQ_P_APQ_P_OPD  APQ_P_APQ_P_PM  APQ_P_APQ_P_PP  \
# count       289.000000       289.000000      289.000000      289.000000
# mean         39.633218        16.726644       15.944637       24.826990
# ...

# %%
df_test_meta_cat = pd.read_excel("./data/test/TEST_CATEGORICAL.xlsx")
print(df_test_meta_cat.shape)

# Display value counts for each column in df_train_meta_cat
for col in df_test_meta_cat.columns[1:]:
  print(f"Value counts for column '{col}':\n{df_test_meta_cat[col].value_counts()}\n")
# Out:
# (304, 10)
# Value counts for column 'Basic_Demos_Enroll_Year':
# Basic_Demos_Enroll_Year
# 2022    232
# 2023     68
# 2020      2
# 2021      1
# 2019      1
# Name: count, dtype: int64
#
# Value counts for column 'Basic_Demos_Study_Site':
# Basic_Demos_Study_Site
# 4    301
# 5      3
# Name: count, dtype: int64
#
# Value counts for column 'PreInt_Demos_Fam_Child_Ethnicity':
# PreInt_Demos_Fam_Child_Ethnicity
# 0.0    221
# 1.0     58
# 2.0     17
# 3.0      5
# Name: count, dtype: int64
#
# Value counts for column 'PreInt_Demos_Fam_Child_Race':
# PreInt_Demos_Fam_Child_Race
# 0.0     168
# 8.0      55
# 1.0      28
# 2.0      23
# 3.0      12
# 11.0      7
# 9.0       3
# 4.0       1
# 7.0       1
# Name: count, dtype: int64
#
# Value counts for column 'MRI_Track_Scan_Location':
# MRI_Track_Scan_Location
# 4    194
# 3    110
# Name: count, dtype: int64
#
# Value counts for column 'Barratt_Barratt_P1_Edu':
# Barratt_Barratt_P1_Edu
# 21.0    170
# 18.0     95
# 15.0     27
# ...
